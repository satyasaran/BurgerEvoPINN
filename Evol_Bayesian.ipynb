# %%
# !pip install deepxde
# Out:
# Collecting deepxde
#   Downloading DeepXDE-1.9.2-py3-none-any.whl (165 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 165.3/165.3 kB 7.5 MB/s eta 0:00:00
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (from deepxde) (3.7.1)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from deepxde) (1.22.4)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.10/dist-packages (from deepxde) (1.2.2)
# Collecting scikit-optimize>=0.9.0 (from deepxde)
#   Downloading scikit_optimize-0.9.0-py2.py3-none-any.whl (100 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 100.3/100.3 kB 12.6 MB/s eta 0:00:00
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from deepxde) (1.10.1)
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.10/dist-packages (from scikit-optimize>=0.9.0->deepxde) (1.3.1)
# Collecting pyaml>=16.9 (from scikit-optimize>=0.9.0->deepxde)
#   Downloading pyaml-23.7.0-py3-none-any.whl (17 kB)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn->deepxde) (3.1.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->deepxde) (1.1.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib->deepxde) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->deepxde) (4.40.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->deepxde) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->deepxde) (23.1)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->deepxde) (8.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->deepxde) (3.1.0)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib->deepxde) (2.8.2)
# Requirement already satisfied: PyYAML in /usr/local/lib/python3.10/dist-packages (from pyaml>=16.9->scikit-optimize>=0.9.0->deepxde) (6.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib->deepxde) (1.16.0)
# Installing collected packages: pyaml, scikit-optimize, deepxde
# Successfully installed deepxde-1.9.2 pyaml-23.7.0 scikit-optimize-0.9.0

# %%
# Importing required libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import random

# Importing DeepXDE library for solving partial differential equations using deep learning
import deepxde as dde

# Importing Scikit-Optimize library for Bayesian hyperparameter optimization
import skopt
from skopt import gp_minimize
from skopt.plots import plot_convergence, plot_objective
from skopt.space import Real, Categorical, Integer
from skopt.utils import use_named_args

# %% [markdown]
# # **Define the PDE with boundary conditions**

# %%
if dde.backend.backend_name == "pytorch":
    sin = dde.backend.pytorch.sin
else:
    from deepxde.backend import tf

    sin = tf.sin


def pde(x, y):
    dy_x = dde.grad.jacobian(y, x, i=0, j=0)
    dy_t = dde.grad.jacobian(y, x, i=0, j=1)
    dy_xx = dde.grad.hessian(y, x, i=0, j=0)
    dy_xxx = dde.grad.hessian(dy_x, x, i=0, j=0)
    dy_xxxx = dde.grad.hessian(dy_xx, x,i=0, j=0)

    return dy_t + y * dy_x +0.5 * dy_xxxx


def create_model(config):
    learning_rate, num_dense_layers, num_dense_nodes, activation,lamda = config

    geom = dde.geometry.Interval(0, 10)
    timedomain = dde.geometry.TimeDomain(0, 1)
    geomtime = dde.geometry.GeometryXTime(geom, timedomain)

    bc = dde.DirichletBC(geomtime, lambda x: 0, lambda _, on_boundary: on_boundary)
    ic = dde.IC(geomtime, lambda x: np.sin((3.0/5)*np.pi * x[:, 0:1]), lambda _, on_initial: on_initial)
    data = dde.data.TimePDE(geomtime, pde, [bc, ic], num_domain=500,  num_boundary=100, num_initial=100,num_test=1000)
    net = dde.maps.FNN(
        [d] + [num_dense_nodes] * num_dense_layers + [1],
        activation,
        "Glorot uniform",
    )

    model = dde.Model(data, net)
    model.compile("adam", lr=learning_rate,loss_weights=[1, lamda, lamda])
    return model

def train_model(model, config):
    early_stopping = dde.callbacks.EarlyStopping( monitor="loss_train", min_delta=1e-8, patience=100)
    #early_stopping = dde.callbacks.EarlyStopping(min_delta=1e-4, patience=10)
    losshistory, train_state = model.train(epochs=epochs,disregard_previous_best=True, callbacks=[early_stopping],display_every=100)
    train = np.array(losshistory.loss_train).sum(axis=1).ravel()
    test = np.array(losshistory.loss_test).sum(axis=1).ravel()
    metric = np.array(losshistory.metrics_test).sum(axis=1).ravel()

    error = test.min()
    return error


# HPO setting
n_calls = 13
dim_learning_rate = Real(low=1e-4, high=5e-2, name="learning_rate", prior="log-uniform")
dim_num_dense_layers = Integer(low=1, high=8, name="num_dense_layers")
dim_num_dense_nodes = Integer(low=5, high=500, name="num_dense_nodes")
dim_activation = Categorical(categories=["sin", "sigmoid", "tanh"], name="activation")
lamda = Real(low=0.01, high=1, name="lamda", prior="log-uniform")


dimensions = [
    dim_learning_rate,
    dim_num_dense_layers,
    dim_num_dense_nodes,
    dim_activation,
    lamda
]

default_parameters = [1e-3, 4, 16, "sin",0.01]


@use_named_args(dimensions=dimensions)
def fitness(learning_rate, num_dense_layers, num_dense_nodes, activation,lamda):

    config = [learning_rate, num_dense_layers, num_dense_nodes, activation,lamda]
    global ITERATION

    print(ITERATION, "it number")
    # Print the hyper-parameters.
    print("learning rate: {0:.1e}".format(learning_rate))
    print("num_dense_layers:", num_dense_layers)
    print("num_dense_nodes:", num_dense_nodes)
    print("activation:", activation)
    print("lamda:", lamda)
    print()

    # Create the neural network with these hyper-parameters.
    model = create_model(config)
    # possibility to change where we save
    error = train_model(model, config)
    # print(accuracy, 'accuracy is')

    if np.isnan(error):
        error = 10**5

    ITERATION += 1
    return error


ITERATION = 0

search_result = gp_minimize(
    func=fitness,
    dimensions=dimensions,
    acq_func="EI",  # Expected Improvement.
    n_calls=n_calls,
    x0=default_parameters,
    random_state=1234,
)

print(search_result.x)

plot_convergence(search_result)
plot_objective(search_result, show_points=True, size=3.8)
# Out:
# 0 it number
# learning rate: 1.0e-03
# num_dense_layers: 4
# num_dense_nodes: 16
# activation: sin
# lamda: 0.01
#
# Compiling model...
# Building feed-forward neural network...
# 'build' took 0.091439 s
# /usr/local/lib/python3.10/dist-packages/deepxde/nn/tensorflow_compat_v1/fnn.py:116: UserWarning: `tf.layers.dense` is deprecated and will be removed in a future version. Please use `tf.keras.layers.Dense` instead.
#   return tf.layers.dense(
# 'compile' took 7.687418 s
#
# Warning: epochs is deprecated and will be removed in a future version. Use iterations instead.
# Training model...
#
# Step      Train loss                        Test loss                         Test metric
# 0         [1.21e-02, 1.88e-04, 6.22e-03]    [1.04e-02, 1.88e-04, 6.22e-03]    []
# 100       [3.87e-05, 3.04e-05, 4.90e-03]    [2.97e-05, 3.04e-05, 4.90e-03]    []
# 200       [1.72e-05, 6.57e-05, 4.80e-03]    [1.35e-05, 6.57e-05, 4.80e-03]    []
# 300       [1.19e-05, 7.82e-05, 4.77e-03]    [1.00e-05, 7.82e-05, 4.77e-03]    []
# 400       [1.15e-05, 8.19e-05, 4.74e-03]    [9.89e-06, 8.19e-05, 4.74e-03]    []
# 500       [1.49e-05, 8.54e-05, 4.70e-03]    [1.25e-05, 8.54e-05, 4.70e-03]    []
# 600       [2.01e-05, 8.62e-05, 4.67e-03]    [1.63e-05, 8.62e-05, 4.67e-03]    []
# 700       [2.50e-05, 8.57e-05, 4.63e-03]    [2.02e-05, 8.57e-05, 4.63e-03]    []
# 800       [2.86e-05, 8.67e-05, 4.58e-03]    [2.22e-05, 8.67e-05, 4.58e-03]    []
# 900       [2.97e-05, 9.24e-05, 4.52e-03]    [2.26e-05, 9.24e-05, 4.52e-03]    []
# 1000      [3.23e-05, 1.01e-04, 4.46e-03]    [2.63e-05, 1.01e-04, 4.46e-03]    []
# 1100      [3.63e-05, 1.12e-04, 4.39e-03]    [3.14e-05, 1.12e-04, 4.39e-03]    []
# 1200      [4.15e-05, 1.26e-04, 4.31e-03]    [3.77e-05, 1.26e-04, 4.31e-03]    []
# 1300      [6.70e-05, 1.50e-04, 4.20e-03]    [5.54e-05, 1.50e-04, 4.20e-03]    []
# 1400      [6.24e-05, 1.84e-04, 4.05e-03]    [5.59e-05, 1.84e-04, 4.05e-03]    []
# 1500      [8.21e-05, 2.12e-04, 3.89e-03]    [6.76e-05, 2.12e-04, 3.89e-03]    []
# 1600      [9.19e-05, 2.26e-04, 3.78e-03]    [7.20e-05, 2.26e-04, 3.78e-03]    []
# 1700      [1.05e-04, 2.39e-04, 3.66e-03]    [7.78e-05, 2.39e-04, 3.66e-03]    []
# 1800      [1.24e-04, 2.43e-04, 3.54e-03]    [9.00e-05, 2.43e-04, 3.54e-03]    []
# 1900      [4.75e-04, 2.55e-04, 3.40e-03]    [3.15e-04, 2.55e-04, 3.40e-03]    []
# Epoch 1900: early stopping
#
# Best model at step 1800:
#   train loss: 3.91e-03
#   test loss: 3.87e-03
#   test metric: []
#
# 'train' took 38.901734 s
#
# 1 it number
# learning rate: 2.2e-03
# num_dense_layers: 7
# num_dense_nodes: 308
# activation: tanh
# lamda: 0.5264286812182277
#
# Compiling model...
# Building feed-forward neural network...
# 'build' took 0.121369 s
#
# 'compile' took 12.379213 s
#
# Warning: epochs is deprecated and will be removed in a future version. Use iterations instead.
# Training model...
#
# Step      Train loss                        Test loss                         Test metric
# 0         [3.48e-03, 8.36e-03, 2.86e-01]    [3.87e-03, 8.36e-03, 2.86e-01]    []
# 100       [7.84e-04, 2.15e-03, 2.54e-01]    [6.36e-04, 2.15e-03, 2.54e-01]    []
# 200       [1.68e-03, 3.14e-03, 2.47e-01]    [1.06e-03, 3.14e-03, 2.47e-01]    []
# 300       [2.31e-03, 3.22e-03, 2.40e-01]    [1.12e-03, 3.22e-03, 2.40e-01]    []
# 400       [1.02e-03, 2.71e-03, 2.58e-01]    [3.73e-04, 2.71e-03, 2.58e-01]    []
# Epoch 400: early stopping
#
# Best model at step 300:
#   train loss: 2.45e-01
#   test loss: 2.44e-01
#   test metric: []
#
# 'train' took 555.876819 s
#
# 2 it number
# learning rate: 2.6e-04
# num_dense_layers: 2
# num_dense_nodes: 409
# activation: sigmoid
# lamda: 0.01707165616739042
#
# Compiling model...
# Building feed-forward neural network...
# 'build' took 0.069349 s
#
# 'compile' took 3.952833 s
#
# Warning: epochs is deprecated and will be removed in a future version. Use iterations instead.
# Training model...
#
# Step      Train loss                        Test loss                         Test metric
# 0         [5.01e-05, 6.18e-03, 1.47e-02]    [5.03e-05, 6.18e-03, 1.47e-02]    []
# 100       [5.43e-07, 9.60e-05, 8.33e-03]    [4.29e-07, 9.60e-05, 8.33e-03]    []
# 200       [5.30e-07, 9.33e-05, 8.34e-03]    [4.20e-07, 9.33e-05, 8.34e-03]    []
# 300       [5.57e-07, 9.32e-05, 8.34e-03]    [4.41e-07, 9.32e-05, 8.34e-03]    []
# 400       [5.87e-07, 9.32e-05, 8.34e-03]    [4.65e-07, 9.32e-05, 8.34e-03]    []
# 500       [6.19e-07, 9.31e-05, 8.34e-03]    [4.90e-07, 9.31e-05, 8.34e-03]    []
# 600       [6.52e-07, 9.30e-05, 8.34e-03]    [5.16e-07, 9.30e-05, 8.34e-03]    []
# 700       [6.85e-07, 9.30e-05, 8.34e-03]    [5.42e-07, 9.30e-05, 8.34e-03]    []
# 800       [7.16e-07, 9.29e-05, 8.34e-03]    [5.66e-07, 9.29e-05, 8.34e-03]    []
# 900       [7.45e-07, 9.29e-05, 8.34e-03]    [5.89e-07, 9.29e-05, 8.34e-03]    []
# 1000      [7.71e-07, 9.28e-05, 8.34e-03]    [6.09e-07, 9.28e-05, 8.34e-03]    []
# 1100      [7.94e-07, 9.28e-05, 8.34e-03]    [6.27e-07, 9.28e-05, 8.34e-03]    []
# 1200      [8.14e-07, 9.28e-05, 8.34e-03]    [6.42e-07, 9.28e-05, 8.34e-03]    []
# 1300      [8.30e-07, 9.28e-05, 8.34e-03]    [6.54e-07, 9.28e-05, 8.34e-03]    []
# 1400      [8.44e-07, 9.27e-05, 8.34e-03]    [6.64e-07, 9.27e-05, 8.34e-03]    []
# 1500      [8.54e-07, 9.27e-05, 8.34e-03]    [6.72e-07, 9.27e-05, 8.34e-03]    []
# 1600      [8.63e-07, 9.27e-05, 8.34e-03]    [6.78e-07, 9.27e-05, 8.34e-03]    []
# 1700      [8.69e-07, 9.27e-05, 8.34e-03]    [6.82e-07, 9.27e-05, 8.34e-03]    []
# 1800      [8.74e-07, 9.27e-05, 8.34e-03]    [6.85e-07, 9.27e-05, 8.34e-03]    []
# 1900      [8.77e-07, 9.27e-05, 8.34e-03]    [6.87e-07, 9.27e-05, 8.34e-03]    []
# 2000      [8.80e-07, 9.27e-05, 8.34e-03]    [6.88e-07, 9.27e-05, 8.34e-03]    []
# 2100      [8.82e-07, 9.27e-05, 8.34e-03]    [6.89e-07, 9.27e-05, 8.34e-03]    []
# 2200      [8.84e-07, 9.27e-05, 8.34e-03]    [6.89e-07, 9.27e-05, 8.34e-03]    []
# 2300      [8.85e-07, 9.27e-05, 8.34e-03]    [6.89e-07, 9.27e-05, 8.34e-03]    []
# 2400      [8.86e-07, 9.27e-05, 8.34e-03]    [6.89e-07, 9.27e-05, 8.34e-03]    []
# 2500      [8.88e-07, 9.27e-05, 8.34e-03]    [6.89e-07, 9.27e-05, 8.34e-03]    []
# 2600      [8.89e-07, 9.27e-05, 8.34e-03]    [6.88e-07, 9.27e-05, 8.34e-03]    []
# 2700      [8.90e-07, 9.27e-05, 8.33e-03]    [6.88e-07, 9.27e-05, 8.33e-03]    []
# 2800      [8.91e-07, 9.27e-05, 8.33e-03]    [6.87e-07, 9.27e-05, 8.33e-03]    []
# 2900      [8.97e-07, 9.28e-05, 8.33e-03]    [6.89e-07, 9.28e-05, 8.33e-03]    []
# 3000      [8.93e-07, 9.27e-05, 8.33e-03]    [6.86e-07, 9.27e-05, 8.33e-03]    []
# 3100      [8.94e-07, 9.27e-05, 8.33e-03]    [6.84e-07, 9.27e-05, 8.33e-03]    []
# 3200      [9.98e-07, 9.53e-05, 8.34e-03]    [7.59e-07, 9.53e-05, 8.34e-03]    []
# Epoch 3200: early stopping
#
# Best model at step 3100:
#   train loss: 8.43e-03
#   test loss: 8.43e-03
#   test metric: []
#
# 'train' took 1220.504317 s
#
# 3 it number
# learning rate: 1.1e-04
# num_dense_layers: 4
# num_dense_nodes: 169
# activation: tanh
# lamda: 0.015721858061410025
#
# Compiling model...
# Building feed-forward neural network...
# 'build' took 0.085814 s
#
# 'compile' took 7.402472 s
#
# Warning: epochs is deprecated and will be removed in a future version. Use iterations instead.
# Training model...
#
# Step      Train loss                        Test loss                         Test metric
# 0         [3.66e-03, 6.22e-05, 7.91e-03]    [3.77e-03, 6.22e-05, 7.91e-03]    []
# 100       [4.53e-06, 8.87e-05, 7.66e-03]    [5.35e-06, 8.87e-05, 7.66e-03]    []
# 200       [4.03e-06, 9.37e-05, 7.65e-03]    [3.50e-06, 9.37e-05, 7.65e-03]    []
# 300       [4.49e-06, 9.74e-05, 7.64e-03]    [3.16e-06, 9.74e-05, 7.64e-03]    []
# 400       [5.50e-06, 1.00e-04, 7.62e-03]    [3.58e-06, 1.00e-04, 7.62e-03]    []
# 500       [6.87e-06, 1.03e-04, 7.61e-03]    [4.47e-06, 1.03e-04, 7.61e-03]    []
# 600       [8.77e-06, 1.05e-04, 7.60e-03]    [5.87e-06, 1.05e-04, 7.60e-03]    []
# 700       [1.13e-05, 1.06e-04, 7.58e-03]    [7.75e-06, 1.06e-04, 7.58e-03]    []
# 800       [1.39e-05, 1.05e-04, 7.56e-03]    [9.28e-06, 1.05e-04, 7.56e-03]    []
# 900       [2.03e-05, 9.83e-05, 7.53e-03]    [1.54e-05, 9.83e-05, 7.53e-03]    []
# 1000      [3.14e-05, 9.35e-05, 7.48e-03]    [2.86e-05, 9.35e-05, 7.48e-03]    []
# 1100      [3.66e-05, 1.03e-04, 7.41e-03]    [3.32e-05, 1.03e-04, 7.41e-03]    []
# 1200      [3.72e-05, 1.16e-04, 7.33e-03]    [3.46e-05, 1.16e-04, 7.33e-03]    []
# 1300      [4.04e-05, 1.41e-04, 7.25e-03]    [4.19e-05, 1.41e-04, 7.25e-03]    []
# 1400      [4.90e-05, 1.44e-04, 7.22e-03]    [5.14e-05, 1.44e-04, 7.22e-03]    []
# 1500      [3.44e-05, 1.78e-04, 7.14e-03]    [3.47e-05, 1.78e-04, 7.14e-03]    []
# 1600      [3.27e-05, 1.97e-04, 7.09e-03]    [3.22e-05, 1.97e-04, 7.09e-03]    []
# 1700      [3.10e-05, 2.08e-04, 7.05e-03]    [3.01e-05, 2.08e-04, 7.05e-03]    []
# 1800      [2.77e-05, 2.19e-04, 7.00e-03]    [2.54e-05, 2.19e-04, 7.00e-03]    []
# 1900      [2.40e-05, 2.23e-04, 6.97e-03]    [2.14e-05, 2.23e-04, 6.97e-03]    []
# 2000      [2.52e-05, 2.30e-04, 6.91e-03]    [2.41e-05, 2.30e-04, 6.91e-03]    []
# 2100      [2.91e-05, 2.25e-04, 6.87e-03]    [2.87e-05, 2.25e-04, 6.87e-03]    []
# 2200      [5.45e-05, 2.16e-04, 6.84e-03]    [4.10e-05, 2.16e-04, 6.84e-03]    []
# 2300      [3.69e-05, 2.11e-04, 6.80e-03]    [3.63e-05, 2.11e-04, 6.80e-03]    []
# 2400      [4.23e-05, 2.04e-04, 6.76e-03]    [4.42e-05, 2.04e-04, 6.76e-03]    []
# 2500      [5.31e-05, 1.91e-04, 6.73e-03]    [5.49e-05, 1.91e-04, 6.73e-03]    []
# 2600      [5.30e-05, 1.92e-04, 6.69e-03]    [5.60e-05, 1.92e-04, 6.69e-03]    []
# 2700      [5.49e-05, 1.86e-04, 6.66e-03]    [5.69e-05, 1.86e-04, 6.66e-03]    []
# 2800      [3.27e-04, 2.05e-04, 6.60e-03]    [1.87e-04, 2.05e-04, 6.60e-03]    []
# Epoch 2800: early stopping
#
# Best model at step 2700:
#   train loss: 6.90e-03
#   test loss: 6.90e-03
#   test metric: []
#
# 'train' took 727.573259 s
#
# 4 it number
# learning rate: 1.4e-04
# num_dense_layers: 4
# num_dense_nodes: 16
# activation: sin
# lamda: 0.03110204078235363
#
# Compiling model...
# Building feed-forward neural network...
# 'build' took 0.082934 s
#
# 'compile' took 8.407735 s
#
# Warning: epochs is deprecated and will be removed in a future version. Use iterations instead.
# Training model...
#
# Step      Train loss                        Test loss                         Test metric
# 0         [5.29e-02, 2.32e-02, 5.14e-02]    [4.24e-02, 2.32e-02, 5.14e-02]    []
# 100       [2.98e-03, 4.59e-03, 2.27e-02]    [2.52e-03, 4.59e-03, 2.27e-02]    []
# 200       [1.46e-03, 2.24e-04, 1.72e-02]    [1.39e-03, 2.24e-04, 1.72e-02]    []
# 300       [9.83e-04, 4.07e-05, 1.58e-02]    [9.83e-04, 4.07e-05, 1.58e-02]    []
# 400       [6.82e-04, 1.25e-04, 1.54e-02]    [7.02e-04, 1.25e-04, 1.54e-02]    []
# 500       [4.56e-04, 1.77e-04, 1.52e-02]    [4.69e-04, 1.77e-04, 1.52e-02]    []
# 600       [3.00e-04, 2.08e-04, 1.51e-02]    [3.01e-04, 2.08e-04, 1.51e-02]    []
# 700       [1.97e-04, 2.27e-04, 1.51e-02]    [1.92e-04, 2.27e-04, 1.51e-02]    []
# 800       [1.32e-04, 2.39e-04, 1.50e-02]    [1.24e-04, 2.39e-04, 1.50e-02]    []
# 900       [9.23e-05, 2.45e-04, 1.50e-02]    [8.25e-05, 2.45e-04, 1.50e-02]    []
# 1000      [6.81e-05, 2.47e-04, 1.50e-02]    [5.81e-05, 2.47e-04, 1.50e-02]    []
# 1100      [5.37e-05, 2.48e-04, 1.50e-02]    [4.34e-05, 2.48e-04, 1.50e-02]    []
# 1200      [4.52e-05, 2.47e-04, 1.50e-02]    [3.45e-05, 2.47e-04, 1.50e-02]    []
# 1300      [4.05e-05, 2.47e-04, 1.49e-02]    [2.92e-05, 2.47e-04, 1.49e-02]    []
# 1400      [3.82e-05, 2.47e-04, 1.49e-02]    [2.62e-05, 2.47e-04, 1.49e-02]    []
# 1500      [3.77e-05, 2.47e-04, 1.49e-02]    [2.48e-05, 2.47e-04, 1.49e-02]    []
# 1600      [3.84e-05, 2.48e-04, 1.49e-02]    [2.47e-05, 2.48e-04, 1.49e-02]    []
# 1700      [4.03e-05, 2.49e-04, 1.49e-02]    [2.57e-05, 2.49e-04, 1.49e-02]    []
# 1800      [4.30e-05, 2.50e-04, 1.49e-02]    [2.75e-05, 2.50e-04, 1.49e-02]    []
# 1900      [4.64e-05, 2.51e-04, 1.48e-02]    [3.00e-05, 2.51e-04, 1.48e-02]    []
# 2000      [5.02e-05, 2.52e-04, 1.48e-02]    [3.30e-05, 2.52e-04, 1.48e-02]    []
# 2100      [5.43e-05, 2.54e-04, 1.48e-02]    [3.62e-05, 2.54e-04, 1.48e-02]    []
# 2200      [5.83e-05, 2.55e-04, 1.48e-02]    [3.95e-05, 2.55e-04, 1.48e-02]    []
# 2300      [6.20e-05, 2.56e-04, 1.47e-02]    [4.27e-05, 2.56e-04, 1.47e-02]    []
# 2400      [6.53e-05, 2.57e-04, 1.47e-02]    [4.56e-05, 2.57e-04, 1.47e-02]    []
# 2500      [6.83e-05, 2.58e-04, 1.47e-02]    [4.82e-05, 2.58e-04, 1.47e-02]    []
# 2600      [7.10e-05, 2.58e-04, 1.47e-02]    [5.06e-05, 2.58e-04, 1.47e-02]    []
# 2700      [7.36e-05, 2.59e-04, 1.47e-02]    [5.30e-05, 2.59e-04, 1.47e-02]    []
# 2800      [7.63e-05, 2.59e-04, 1.46e-02]    [5.55e-05, 2.59e-04, 1.46e-02]    []
# 2900      [7.93e-05, 2.59e-04, 1.46e-02]    [5.83e-05, 2.59e-04, 1.46e-02]    []
# 3000      [8.28e-05, 2.59e-04, 1.45e-02]    [6.15e-05, 2.59e-04, 1.45e-02]    []
# 3100      [8.68e-05, 2.60e-04, 1.45e-02]    [6.53e-05, 2.60e-04, 1.45e-02]    []
# 3200      [9.13e-05, 2.61e-04, 1.45e-02]    [6.94e-05, 2.61e-04, 1.45e-02]    []
# 3300      [9.62e-05, 2.62e-04, 1.44e-02]    [7.36e-05, 2.62e-04, 1.44e-02]    []
# 3400      [1.01e-04, 2.64e-04, 1.43e-02]    [7.75e-05, 2.64e-04, 1.43e-02]    []
# 3500      [1.06e-04, 2.66e-04, 1.43e-02]    [8.08e-05, 2.66e-04, 1.43e-02]    []
# 3600      [1.09e-04, 2.70e-04, 1.42e-02]    [8.33e-05, 2.70e-04, 1.42e-02]    []
# 3700      [1.12e-04, 2.76e-04, 1.42e-02]    [8.48e-05, 2.76e-04, 1.42e-02]    []
# 3800      [1.14e-04, 2.84e-04, 1.41e-02]    [8.57e-05, 2.84e-04, 1.41e-02]    []
# 3900      [1.14e-04, 2.93e-04, 1.40e-02]    [8.60e-05, 2.93e-04, 1.40e-02]    []
# 4000      [1.12e-04, 3.05e-04, 1.39e-02]    [8.59e-05, 3.05e-04, 1.39e-02]    []
# 4100      [1.10e-04, 3.21e-04, 1.39e-02]    [8.62e-05, 3.21e-04, 1.39e-02]    []
# 4200      [1.10e-04, 3.38e-04, 1.37e-02]    [8.92e-05, 3.38e-04, 1.37e-02]    []
# 4300      [1.17e-04, 3.59e-04, 1.36e-02]    [9.81e-05, 3.59e-04, 1.36e-02]    []
# 4400      [1.27e-04, 3.81e-04, 1.35e-02]    [1.11e-04, 3.81e-04, 1.35e-02]    []
# 4500      [1.38e-04, 4.06e-04, 1.34e-02]    [1.26e-04, 4.06e-04, 1.34e-02]    []
# 4600      [1.51e-04, 4.33e-04, 1.33e-02]    [1.43e-04, 4.33e-04, 1.33e-02]    []
# 4700      [1.64e-04, 4.63e-04, 1.32e-02]    [1.61e-04, 4.63e-04, 1.32e-02]    []
# 4800      [1.77e-04, 4.94e-04, 1.30e-02]    [1.76e-04, 4.94e-04, 1.30e-02]    []
# 4900      [1.89e-04, 5.26e-04, 1.29e-02]    [1.88e-04, 5.26e-04, 1.29e-02]    []
# 5000      [1.99e-04, 5.59e-04, 1.28e-02]    [1.97e-04, 5.59e-04, 1.28e-02]    []
# 5100      [2.08e-04, 5.90e-04, 1.26e-02]    [2.02e-04, 5.90e-04, 1.26e-02]    []
# 5200      [2.16e-04, 6.19e-04, 1.25e-02]    [2.06e-04, 6.19e-04, 1.25e-02]    []
# 5300      [2.23e-04, 6.42e-04, 1.23e-02]    [2.05e-04, 6.42e-04, 1.23e-02]    []
# 5400      [2.28e-04, 6.56e-04, 1.21e-02]    [2.02e-04, 6.56e-04, 1.21e-02]    []
# 5500      [2.36e-04, 6.57e-04, 1.19e-02]    [2.03e-04, 6.57e-04, 1.19e-02]    []
# 5600      [2.55e-04, 6.46e-04, 1.15e-02]    [2.24e-04, 6.46e-04, 1.15e-02]    []
# 5700      [2.94e-04, 6.27e-04, 1.10e-02]    [2.86e-04, 6.27e-04, 1.10e-02]    []
# 5800      [3.71e-04, 6.01e-04, 1.04e-02]    [4.00e-04, 6.01e-04, 1.04e-02]    []
# 5900      [4.52e-04, 5.87e-04, 9.83e-03]    [5.23e-04, 5.87e-04, 9.83e-03]    []
# 6000      [5.07e-04, 5.75e-04, 9.23e-03]    [6.20e-04, 5.75e-04, 9.23e-03]    []
# 6100      [5.58e-04, 5.57e-04, 8.63e-03]    [6.90e-04, 5.57e-04, 8.63e-03]    []
# 6200      [5.91e-04, 5.53e-04, 8.03e-03]    [7.01e-04, 5.53e-04, 8.03e-03]    []
# 6300      [6.15e-04, 5.54e-04, 7.46e-03]    [6.83e-04, 5.54e-04, 7.46e-03]    []
# 6400      [6.41e-04, 5.66e-04, 6.94e-03]    [6.88e-04, 5.66e-04, 6.94e-03]    []
# 6500      [6.67e-04, 5.70e-04, 6.48e-03]    [7.49e-04, 5.70e-04, 6.48e-03]    []
# 6600      [6.80e-04, 5.74e-04, 6.08e-03]    [7.92e-04, 5.74e-04, 6.08e-03]    []
# 6700      [6.86e-04, 5.73e-04, 5.70e-03]    [8.23e-04, 5.73e-04, 5.70e-03]    []
# 6800      [6.76e-04, 5.64e-04, 5.36e-03]    [8.59e-04, 5.64e-04, 5.36e-03]    []
# 6900      [6.62e-04, 5.56e-04, 5.04e-03]    [8.54e-04, 5.56e-04, 5.04e-03]    []
# 7000      [6.42e-04, 5.44e-04, 4.72e-03]    [8.79e-04, 5.44e-04, 4.72e-03]    []
# 7100      [6.05e-04, 5.35e-04, 4.42e-03]    [8.44e-04, 5.35e-04, 4.42e-03]    []
# 7200      [5.72e-04, 5.17e-04, 4.12e-03]    [8.44e-04, 5.17e-04, 4.12e-03]    []
# 7300      [5.40e-04, 4.94e-04, 3.84e-03]    [8.43e-04, 4.94e-04, 3.84e-03]    []
# 7400      [5.19e-04, 4.69e-04, 3.59e-03]    [8.41e-04, 4.69e-04, 3.59e-03]    []
# 7500      [4.95e-04, 4.43e-04, 3.35e-03]    [8.20e-04, 4.43e-04, 3.35e-03]    []
# 7600      [4.83e-04, 4.15e-04, 3.13e-03]    [7.92e-04, 4.15e-04, 3.13e-03]    []
# 7700      [4.59e-04, 3.89e-04, 2.93e-03]    [7.70e-04, 3.89e-04, 2.93e-03]    []
# 7800      [4.45e-04, 3.63e-04, 2.74e-03]    [7.36e-04, 3.63e-04, 2.74e-03]    []
# 7900      [4.40e-04, 3.39e-04, 2.58e-03]    [7.22e-04, 3.39e-04, 2.58e-03]    []
# 8000      [4.28e-04, 3.17e-04, 2.43e-03]    [6.94e-04, 3.17e-04, 2.43e-03]    []
# 8100      [4.23e-04, 2.98e-04, 2.31e-03]    [6.83e-04, 2.98e-04, 2.31e-03]    []
# 8200      [4.37e-04, 2.79e-04, 2.19e-03]    [6.79e-04, 2.79e-04, 2.19e-03]    []
# 8300      [4.20e-04, 2.64e-04, 2.09e-03]    [6.62e-04, 2.64e-04, 2.09e-03]    []
# 8400      [4.20e-04, 2.49e-04, 2.01e-03]    [6.52e-04, 2.49e-04, 2.01e-03]    []
# 8500      [4.47e-04, 2.35e-04, 1.92e-03]    [6.79e-04, 2.35e-04, 1.92e-03]    []
# 8600      [4.17e-04, 2.22e-04, 1.85e-03]    [6.27e-04, 2.22e-04, 1.85e-03]    []
# 8700      [4.16e-04, 2.10e-04, 1.78e-03]    [6.15e-04, 2.10e-04, 1.78e-03]    []
# 8800      [4.15e-04, 1.99e-04, 1.72e-03]    [6.02e-04, 1.99e-04, 1.72e-03]    []
# 8900      [4.13e-04, 1.88e-04, 1.67e-03]    [5.91e-04, 1.88e-04, 1.67e-03]    []
# 9000      [4.04e-04, 1.78e-04, 1.61e-03]    [5.72e-04, 1.78e-04, 1.61e-03]    []
# 9100      [4.00e-04, 1.69e-04, 1.57e-03]    [5.60e-04, 1.69e-04, 1.57e-03]    []
# 9200      [3.97e-04, 1.60e-04, 1.52e-03]    [5.49e-04, 1.60e-04, 1.52e-03]    []
# 9300      [4.18e-04, 1.52e-04, 1.48e-03]    [5.74e-04, 1.52e-04, 1.48e-03]    []
# 9400      [3.99e-04, 1.45e-04, 1.44e-03]    [5.37e-04, 1.45e-04, 1.44e-03]    []
# 9500      [4.04e-04, 1.38e-04, 1.39e-03]    [5.41e-04, 1.38e-04, 1.39e-03]    []
# 9600      [3.82e-04, 1.32e-04, 1.36e-03]    [5.18e-04, 1.32e-04, 1.36e-03]    []
# 9700      [3.80e-04, 1.26e-04, 1.32e-03]    [5.15e-04, 1.26e-04, 1.32e-03]    []
# 9800      [3.77e-04, 1.21e-04, 1.29e-03]    [5.11e-04, 1.21e-04, 1.29e-03]    []
# 9900      [3.74e-04, 1.16e-04, 1.26e-03]    [5.09e-04, 1.16e-04, 1.26e-03]    []
# 10000     [3.81e-04, 1.11e-04, 1.23e-03]    [5.17e-04, 1.11e-04, 1.23e-03]    []
#
# Best model at step 10000:
#   train loss: 1.72e-03
#   test loss: 1.85e-03
#   test metric: []
#
# 'train' took 182.573337 s
#
# 5 it number
# learning rate: 9.8e-03
# num_dense_layers: 7
# num_dense_nodes: 494
# activation: sigmoid
# lamda: 0.0613147136799765
#
# Compiling model...
# Building feed-forward neural network...
# 'build' took 0.131701 s
#
# 'compile' took 16.235956 s
#
# Warning: epochs is deprecated and will be removed in a future version. Use iterations instead.
# Training model...
#
# Step      Train loss                        Test loss                         Test metric
# 0         [3.04e-12, 7.02e-02, 1.00e-01]    [2.99e-12, 7.02e-02, 1.00e-01]    []
# 100       [7.66e-27, 1.92e-05, 3.07e-02]    [7.64e-27, 1.92e-05, 3.07e-02]    []
# 200       [7.50e-27, 1.84e-07, 3.07e-02]    [7.48e-27, 1.84e-07, 3.07e-02]    []
# 300       [7.50e-27, 1.74e-07, 3.07e-02]    [7.48e-27, 1.74e-07, 3.07e-02]    []
# Epoch 300: early stopping
#
# Best model at step 200:
#   train loss: 3.07e-02
#   test loss: 3.07e-02
#   test metric: []
#
# 'train' took 874.325796 s
#
# 6 it number
# learning rate: 1.7e-03
# num_dense_layers: 5
# num_dense_nodes: 396
# activation: sin
# lamda: 0.07424453733033923
#
# Compiling model...
# Building feed-forward neural network...
# 'build' took 0.106760 s
#
# 'compile' took 10.769990 s
#
# Warning: epochs is deprecated and will be removed in a future version. Use iterations instead.
# Training model...
#
# Step      Train loss                        Test loss                         Test metric
# 0         [8.18e-03, 3.93e-02, 8.72e-02]    [9.18e-03, 3.93e-02, 8.72e-02]    []
# 100       [2.46e-04, 4.14e-04, 3.57e-02]    [1.89e-04, 4.14e-04, 3.57e-02]    []
# 200       [2.20e-04, 5.53e-04, 3.53e-02]    [1.53e-04, 5.53e-04, 3.53e-02]    []
# 300       [2.41e-04, 5.61e-04, 3.50e-02]    [1.72e-04, 5.61e-04, 3.50e-02]    []
# 400       [1.41e-04, 6.13e-04, 3.53e-02]    [9.47e-05, 6.13e-04, 3.53e-02]    []
# Epoch 400: early stopping
#
# Best model at step 300:
#   train loss: 3.58e-02
#   test loss: 3.57e-02
#   test metric: []
#
# 'train' took 546.888186 s
#
# 7 it number
# learning rate: 3.4e-03
# num_dense_layers: 8
# num_dense_nodes: 25
# activation: sin
# lamda: 0.08416920135371565
#
# Compiling model...
# Building feed-forward neural network...
# 'build' took 0.139137 s
#
# 'compile' took 18.083097 s
#
# Warning: epochs is deprecated and will be removed in a future version. Use iterations instead.
# Training model...
#
# Step      Train loss                        Test loss                         Test metric
# 0         [1.14e-01, 2.12e-02, 1.22e-01]    [1.01e-01, 2.12e-02, 1.22e-01]    []
# 100       [2.04e-04, 5.56e-04, 4.01e-02]    [1.75e-04, 5.56e-04, 4.01e-02]    []
# 200       [5.10e-04, 9.87e-04, 3.71e-02]    [3.71e-04, 9.87e-04, 3.71e-02]    []
# 300       [8.14e-04, 1.35e-03, 3.49e-02]    [6.65e-04, 1.35e-03, 3.49e-02]    []
# 400       [5.57e-04, 9.08e-04, 3.37e-02]    [5.86e-04, 9.08e-04, 3.37e-02]    []
# 500       [1.96e-03, 1.95e-03, 3.14e-02]    [9.83e-04, 1.95e-03, 3.14e-02]    []
# Epoch 500: early stopping
#
# Best model at step 400:
#   train loss: 3.52e-02
#   test loss: 3.52e-02
#   test metric: []
#
# 'train' took 50.404757 s
#
# 8 it number
# learning rate: 1.0e-03
# num_dense_layers: 3
# num_dense_nodes: 408
# activation: sin
# lamda: 0.012440933109455316
#
# Compiling model...
# Building feed-forward neural network...
# 'build' took 0.067406 s
#
# 'compile' took 6.092805 s
#
# Warning: epochs is deprecated and will be removed in a future version. Use iterations instead.
# Training model...
#
# Step      Train loss                        Test loss                         Test metric
# 0         [7.44e-03, 3.56e-04, 6.52e-03]    [7.47e-03, 3.56e-04, 6.52e-03]    []
# 100       [7.00e-06, 1.22e-04, 5.99e-03]    [7.93e-06, 1.22e-04, 5.99e-03]    []
# 200       [2.97e-06, 1.06e-04, 6.01e-03]    [2.94e-06, 1.06e-04, 6.01e-03]    []
# 300       [2.10e-06, 1.05e-04, 6.01e-03]    [2.00e-06, 1.05e-04, 6.01e-03]    []
# 400       [1.72e-06, 1.04e-04, 6.00e-03]    [1.40e-06, 1.04e-04, 6.00e-03]    []
# 500       [1.81e-06, 1.04e-04, 6.00e-03]    [1.19e-06, 1.04e-04, 6.00e-03]    []
# 600       [2.37e-06, 1.04e-04, 6.00e-03]    [1.40e-06, 1.04e-04, 6.00e-03]    []
# 700       [3.10e-06, 1.03e-04, 5.99e-03]    [1.81e-06, 1.03e-04, 5.99e-03]    []
# 800       [3.78e-06, 1.03e-04, 5.99e-03]    [2.24e-06, 1.03e-04, 5.99e-03]    []
# 900       [4.41e-06, 1.02e-04, 5.98e-03]    [2.62e-06, 1.02e-04, 5.98e-03]    []
# 1000      [5.09e-06, 1.02e-04, 5.98e-03]    [2.97e-06, 1.02e-04, 5.98e-03]    []
# 1100      [6.43e-06, 1.02e-04, 5.96e-03]    [3.59e-06, 1.02e-04, 5.96e-03]    []
# 1200      [1.12e-05, 1.01e-04, 5.94e-03]    [5.91e-06, 1.01e-04, 5.94e-03]    []
# 1300      [2.10e-05, 9.98e-05, 5.91e-03]    [1.08e-05, 9.98e-05, 5.91e-03]    []
# 1400      [2.74e-05, 9.93e-05, 5.89e-03]    [1.37e-05, 9.93e-05, 5.89e-03]    []
# 1500      [3.03e-05, 9.89e-05, 5.87e-03]    [1.47e-05, 9.89e-05, 5.87e-03]    []
# 1600      [3.24e-05, 9.82e-05, 5.86e-03]    [1.53e-05, 9.82e-05, 5.86e-03]    []
# 1700      [3.32e-05, 9.64e-05, 5.84e-03]    [1.56e-05, 9.64e-05, 5.84e-03]    []
# 1800      [2.44e-05, 9.01e-05, 5.80e-03]    [1.30e-05, 9.01e-05, 5.80e-03]    []
# 1900      [1.07e-03, 1.15e-03, 7.42e-03]    [1.47e-03, 1.15e-03, 7.42e-03]    []
# Epoch 1900: early stopping
#
# Best model at step 1800:
#   train loss: 5.92e-03
#   test loss: 5.91e-03
#   test metric: []
#
# 'train' took 1282.561862 s
#
# 9 it number
# learning rate: 4.8e-02
# num_dense_layers: 6
# num_dense_nodes: 465
# activation: tanh
# lamda: 0.8924901842102502
#
# Compiling model...
# Building feed-forward neural network...
# 'build' took 0.123192 s
#
# 'compile' took 12.825744 s
#
# Warning: epochs is deprecated and will be removed in a future version. Use iterations instead.
# Training model...
#
# Step      Train loss                        Test loss                         Test metric
# 0         [4.07e-03, 6.00e-03, 4.41e-01]    [3.75e-03, 6.00e-03, 4.41e-01]    []
# 100       [nan, nan, nan]                   [nan, nan, nan]                   []
#
# Best model at step 0:
#   train loss: 4.51e-01
#   test loss: 4.51e-01
#   test metric: []
#
# 'train' took 239.694618 s
#
# 10 it number
# learning rate: 1.2e-03
# num_dense_layers: 3
# num_dense_nodes: 218
# activation: tanh
# lamda: 0.15829296926918535
#
# Compiling model...
# Building feed-forward neural network...
# 'build' took 0.111961 s
#
# 'compile' took 6.172709 s
#
# Warning: epochs is deprecated and will be removed in a future version. Use iterations instead.
# Training model...
#
# Step      Train loss                        Test loss                         Test metric
# 0         [3.81e-03, 3.15e-03, 8.50e-02]    [3.94e-03, 3.15e-03, 8.50e-02]    []
# 100       [1.05e-04, 9.75e-04, 7.68e-02]    [9.52e-05, 9.75e-04, 7.68e-02]    []
# 200       [7.37e-05, 9.53e-04, 7.68e-02]    [5.83e-05, 9.53e-04, 7.68e-02]    []
# 300       [8.13e-05, 9.89e-04, 7.66e-02]    [5.85e-05, 9.89e-04, 7.66e-02]    []
# 400       [1.37e-04, 1.01e-03, 7.62e-02]    [1.01e-04, 1.01e-03, 7.62e-02]    []
# 500       [2.68e-04, 1.04e-03, 7.58e-02]    [2.02e-04, 1.04e-03, 7.58e-02]    []
# 600       [3.36e-04, 1.06e-03, 7.56e-02]    [2.44e-04, 1.06e-03, 7.56e-02]    []
# 700       [3.80e-04, 1.07e-03, 7.53e-02]    [2.63e-04, 1.07e-03, 7.53e-02]    []
# 800       [4.23e-04, 1.09e-03, 7.50e-02]    [2.84e-04, 1.09e-03, 7.50e-02]    []
# 900       [4.65e-04, 1.13e-03, 7.45e-02]    [3.01e-04, 1.13e-03, 7.45e-02]    []
# 1000      [4.84e-04, 1.23e-03, 7.38e-02]    [2.91e-04, 1.23e-03, 7.38e-02]    []
# 1100      [5.74e-04, 1.52e-03, 7.21e-02]    [4.29e-04, 1.52e-03, 7.21e-02]    []
# 1200      [7.00e-04, 1.94e-03, 7.04e-02]    [5.10e-04, 1.94e-03, 7.04e-02]    []
# 1300      [7.35e-04, 2.14e-03, 6.88e-02]    [4.53e-04, 2.14e-03, 6.88e-02]    []
# 1400      [1.06e-03, 1.91e-03, 6.68e-02]    [8.02e-04, 1.91e-03, 6.68e-02]    []
# 1500      [5.03e-03, 3.31e-03, 6.41e-02]    [3.82e-03, 3.31e-03, 6.41e-02]    []
# Epoch 1500: early stopping
#
# Best model at step 1400:
#   train loss: 6.98e-02
#   test loss: 6.95e-02
#   test metric: []
#
# 'train' took 386.806143 s
#
# 11 it number
# learning rate: 1.9e-03
# num_dense_layers: 1
# num_dense_nodes: 230
# activation: sin
# lamda: 0.01658914276902891
#
# Compiling model...
# Building feed-forward neural network...
# 'build' took 0.051003 s
# /usr/local/lib/python3.10/dist-packages/deepxde/nn/tensorflow_compat_v1/fnn.py:116: UserWarning: `tf.layers.dense` is deprecated and will be removed in a future version. Please use `tf.keras.layers.Dense` instead.
#   return tf.layers.dense(
# 'compile' took 2.928502 s
#
# Warning: epochs is deprecated and will be removed in a future version. Use iterations instead.
# Training model...
#
# Step      Train loss                        Test loss                         Test metric
# 0         [2.91e-02, 2.22e-03, 9.37e-03]    [2.92e-02, 2.22e-03, 9.37e-03]    []
# 100       [9.19e-06, 8.78e-05, 8.10e-03]    [8.54e-06, 8.78e-05, 8.10e-03]    []
# 200       [5.85e-06, 8.89e-05, 8.10e-03]    [5.47e-06, 8.89e-05, 8.10e-03]    []
# 300       [3.52e-06, 8.90e-05, 8.10e-03]    [3.15e-06, 8.90e-05, 8.10e-03]    []
# 400       [2.13e-06, 8.92e-05, 8.10e-03]    [1.76e-06, 8.92e-05, 8.10e-03]    []
# 500       [1.42e-06, 8.94e-05, 8.10e-03]    [1.06e-06, 8.94e-05, 8.10e-03]    []
# 600       [1.10e-06, 8.96e-05, 8.10e-03]    [7.47e-07, 8.96e-05, 8.10e-03]    []
# 700       [9.80e-07, 9.00e-05, 8.10e-03]    [6.17e-07, 9.00e-05, 8.10e-03]    []
# 800       [9.44e-07, 9.03e-05, 8.10e-03]    [5.63e-07, 9.03e-05, 8.10e-03]    []
# 900       [9.45e-07, 9.07e-05, 8.10e-03]    [5.39e-07, 9.07e-05, 8.10e-03]    []
# 1000      [9.64e-07, 9.11e-05, 8.10e-03]    [5.28e-07, 9.11e-05, 8.10e-03]    []
# 1100      [9.96e-07, 9.16e-05, 8.09e-03]    [5.24e-07, 9.16e-05, 8.09e-03]    []
# 1200      [1.04e-06, 9.22e-05, 8.09e-03]    [5.25e-07, 9.22e-05, 8.09e-03]    []
# 1300      [1.10e-06, 9.28e-05, 8.09e-03]    [5.32e-07, 9.28e-05, 8.09e-03]    []
# 1400      [1.18e-06, 9.36e-05, 8.09e-03]    [5.49e-07, 9.36e-05, 8.09e-03]    []
# 1500      [1.30e-06, 9.47e-05, 8.09e-03]    [5.83e-07, 9.47e-05, 8.09e-03]    []
# 1600      [1.55e-06, 9.66e-05, 8.08e-03]    [6.71e-07, 9.66e-05, 8.08e-03]    []
# 1700      [2.43e-06, 1.02e-04, 8.07e-03]    [1.06e-06, 1.02e-04, 8.07e-03]    []
# 1800      [4.55e-06, 1.18e-04, 8.05e-03]    [1.77e-06, 1.18e-04, 8.05e-03]    []
# 1900      [4.37e-06, 1.24e-04, 8.04e-03]    [1.55e-06, 1.24e-04, 8.04e-03]    []
# 2000      [3.96e-06, 1.26e-04, 8.04e-03]    [1.35e-06, 1.26e-04, 8.04e-03]    []
# 2100      [3.08e-06, 1.31e-04, 8.03e-03]    [1.02e-06, 1.31e-04, 8.03e-03]    []
# 2200      [2.74e-06, 1.19e-04, 8.03e-03]    [2.10e-06, 1.19e-04, 8.03e-03]    []
# 2300      [4.11e-06, 1.42e-04, 8.00e-03]    [4.28e-06, 1.42e-04, 8.00e-03]    []
# 2400      [6.10e-06, 1.43e-04, 7.98e-03]    [6.88e-06, 1.43e-04, 7.98e-03]    []
# 2500      [5.60e-06, 1.50e-04, 7.96e-03]    [6.49e-06, 1.50e-04, 7.96e-03]    []
# 2600      [7.84e-06, 1.50e-04, 7.93e-03]    [8.01e-06, 1.50e-04, 7.93e-03]    []
# 2700      [9.11e-06, 1.60e-04, 7.90e-03]    [9.37e-06, 1.60e-04, 7.90e-03]    []
# 2800      [1.26e-05, 1.49e-04, 7.88e-03]    [1.22e-05, 1.49e-04, 7.88e-03]    []
# 2900      [2.29e-05, 1.26e-04, 7.84e-03]    [1.99e-05, 1.26e-04, 7.84e-03]    []
# 3000      [2.78e-05, 1.88e-04, 7.71e-03]    [3.03e-05, 1.88e-04, 7.71e-03]    []
# 3100      [4.51e-05, 1.38e-04, 7.68e-03]    [4.33e-05, 1.38e-04, 7.68e-03]    []
# 3200      [4.70e-05, 1.47e-04, 7.65e-03]    [4.77e-05, 1.47e-04, 7.65e-03]    []
# 3300      [5.00e-05, 1.36e-04, 7.65e-03]    [4.79e-05, 1.36e-04, 7.65e-03]    []
# 3400      [9.44e-05, 9.39e-05, 7.71e-03]    [5.58e-05, 9.39e-05, 7.71e-03]    []
# Epoch 3400: early stopping
#
# Best model at step 3300:
#   train loss: 7.84e-03
#   test loss: 7.83e-03
#   test metric: []
#
# 'train' took 48.041221 s
#
# 12 it number
# learning rate: 6.8e-03
# num_dense_layers: 1
# num_dense_nodes: 500
# activation: tanh
# lamda: 1.0
#
# Compiling model...
# Building feed-forward neural network...
# 'build' took 0.037686 s
# /usr/local/lib/python3.10/dist-packages/deepxde/nn/tensorflow_compat_v1/fnn.py:116: UserWarning: `tf.layers.dense` is deprecated and will be removed in a future version. Please use `tf.keras.layers.Dense` instead.
#   return tf.layers.dense(
# 'compile' took 2.575117 s
#
# Warning: epochs is deprecated and will be removed in a future version. Use iterations instead.
# Training model...
#
# Step      Train loss                        Test loss                         Test metric
# 0         [3.88e-03, 2.53e-01, 7.51e-01]    [3.98e-03, 2.53e-01, 7.51e-01]    []
# 100       [8.68e-04, 5.18e-03, 4.86e-01]    [7.13e-04, 5.18e-03, 4.86e-01]    []
# 200       [1.50e-03, 4.73e-03, 4.85e-01]    [1.22e-03, 4.73e-03, 4.85e-01]    []
# 300       [1.58e-03, 4.74e-03, 4.85e-01]    [1.28e-03, 4.74e-03, 4.85e-01]    []
# 400       [1.60e-03, 4.76e-03, 4.85e-01]    [1.29e-03, 4.76e-03, 4.85e-01]    []
# 500       [1.61e-03, 4.78e-03, 4.85e-01]    [1.30e-03, 4.78e-03, 4.85e-01]    []
# 600       [1.63e-03, 4.81e-03, 4.85e-01]    [1.31e-03, 4.81e-03, 4.85e-01]    []
# 700       [1.65e-03, 4.85e-03, 4.85e-01]    [1.32e-03, 4.85e-03, 4.85e-01]    []
# 800       [1.69e-03, 4.91e-03, 4.85e-01]    [1.33e-03, 4.91e-03, 4.85e-01]    []
# 900       [1.74e-03, 5.00e-03, 4.84e-01]    [1.34e-03, 5.00e-03, 4.84e-01]    []
# 1000      [1.81e-03, 5.14e-03, 4.84e-01]    [1.35e-03, 5.14e-03, 4.84e-01]    []
# 1100      [1.94e-03, 5.35e-03, 4.83e-01]    [1.32e-03, 5.35e-03, 4.83e-01]    []
# 1200      [2.18e-03, 5.66e-03, 4.81e-01]    [1.28e-03, 5.66e-03, 4.81e-01]    []
# 1300      [2.55e-03, 6.04e-03, 4.80e-01]    [1.27e-03, 6.04e-03, 4.80e-01]    []
# 1400      [2.92e-03, 6.47e-03, 4.78e-01]    [1.33e-03, 6.47e-03, 4.78e-01]    []
# 1500      [3.24e-03, 6.90e-03, 4.77e-01]    [1.44e-03, 6.90e-03, 4.77e-01]    []
# 1600      [3.58e-03, 7.33e-03, 4.75e-01]    [1.63e-03, 7.33e-03, 4.75e-01]    []
# 1700      [3.56e-03, 6.04e-03, 4.75e-01]    [1.68e-03, 6.04e-03, 4.75e-01]    []
# 1800      [4.44e-03, 8.53e-03, 4.66e-01]    [2.32e-03, 8.53e-03, 4.66e-01]    []
# 1900      [5.41e-03, 9.13e-03, 4.60e-01]    [2.89e-03, 9.13e-03, 4.60e-01]    []
# 2000      [6.78e-03, 1.00e-02, 4.52e-01]    [3.81e-03, 1.00e-02, 4.52e-01]    []
# 2100      [8.00e-03, 1.02e-02, 4.47e-01]    [5.44e-03, 1.02e-02, 4.47e-01]    []
# 2200      [7.93e-03, 9.38e-03, 4.46e-01]    [5.62e-03, 9.38e-03, 4.46e-01]    []
# 2300      [8.01e-03, 9.84e-03, 4.43e-01]    [5.81e-03, 9.84e-03, 4.43e-01]    []
# 2400      [8.21e-03, 9.87e-03, 4.40e-01]    [6.08e-03, 9.87e-03, 4.40e-01]    []
# 2500      [8.64e-03, 1.01e-02, 4.37e-01]    [6.55e-03, 1.01e-02, 4.37e-01]    []
# 2600      [8.59e-03, 8.97e-03, 4.38e-01]    [6.67e-03, 8.97e-03, 4.38e-01]    []
# 2700      [8.49e-03, 1.14e-02, 4.31e-01]    [6.90e-03, 1.14e-02, 4.31e-01]    []
# 2800      [9.32e-03, 1.18e-02, 4.25e-01]    [7.58e-03, 1.18e-02, 4.25e-01]    []
# 2900      [9.93e-03, 1.18e-02, 4.22e-01]    [8.45e-03, 1.18e-02, 4.22e-01]    []
# 3000      [8.93e-03, 1.72e-02, 4.18e-01]    [7.74e-03, 1.72e-02, 4.18e-01]    []
# Epoch 3000: early stopping
#
# Best model at step 2900:
#   train loss: 4.44e-01
#   test loss: 4.42e-01
#   test metric: []
#
# 'train' took 115.478382 s
#
# [0.00014162001602662018, 4, 16, 'sin', 0.03110204078235363]
# array([[<Axes: xlabel='learning_rate', ylabel='Partial dependence'>,
#         <Axes: >, <Axes: >, <Axes: >, <Axes: >],
#        [<Axes: ylabel='num_dense_layers'>,
#         <Axes: xlabel='num_dense_layers', ylabel='Partial dependence'>,
#         <Axes: >, <Axes: >, <Axes: >],
#        [<Axes: ylabel='num_dense_nodes'>, <Axes: >,
#         <Axes: xlabel='num_dense_nodes', ylabel='Partial dependence'>,
#         <Axes: >, <Axes: >],
#        [<Axes: ylabel='activation'>, <Axes: >, <Axes: >,
#         <Axes: xlabel='activation', ylabel='Partial dependence'>,
#         <Axes: >],
#        [<Axes: xlabel='learning_rate', ylabel='lamda'>,
#         <Axes: xlabel='num_dense_layers'>,
#         <Axes: xlabel='num_dense_nodes'>, <Axes: xlabel='activation'>,
#         <Axes: xlabel='lamda', ylabel='Partial dependence'>]],
#       dtype=object)
